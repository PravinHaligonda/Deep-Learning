# %% [markdown]
# Convolution is special kind of linear operation.
#
# Convolution networks are simply neural networks that uses convolution in place of general matrix multiplication in at least one of their layers.
